# %%
from weights_aggregation.fed_avg import FedAvgStrategy
from io import BytesIO

# %%
strategy = FedAvgStrategy()

# %%
input = []

for i in range(17, 20):
    weights_path = f'output/experiment_{i}/weights/weights.pth'
    additional_data_path = f'output/experiment_{i}/additional_data/additional_data.csv'

    weights_buffer = None
    with open(weights_path, 'rb') as file:
        weights_buffer = BytesIO(file.read())

    add_info_buffer = None
    with open(additional_data_path, 'rb') as file:
        add_info_buffer = BytesIO(file.read())

    input.append((weights_buffer, add_info_buffer))

# %%
input
# Out:
# [(<_io.BytesIO at 0x145ac7830>, <_io.BytesIO at 0x145ac7c90>),
#  (<_io.BytesIO at 0x145ac74c0>, <_io.BytesIO at 0x145add030>),
#  (<_io.BytesIO at 0x145add120>, <_io.BytesIO at 0x145add170>)]

# %%
strategy.aggregate_train(input)
# Out:
# 369
# 369
# 369
# OrderedDict([('first_conv_layer.weight',
#               tensor([[[ 0.2336,  0.4697]],
#
#                       [[-0.0058,  0.2509]],
#
#                       [[ 0.2312, -0.0131]],
#
#                       [[-0.1260, -0.1835]],
#
#                       [[-0.1086, -0.0477]],
#
#                       [[-0.4764,  0.1092]],
#
#                       [[-0.3551, -0.1417]],
#
#                       [[ 0.3667, -0.2443]],
#
#                       [[ 0.0168, -0.0263]],
#
#                       [[-0.3231, -0.3343]],
#
#                       [[ 0.0773,  0.0068]],
#
#                       [[ 0.3640,  0.3287]],
#
#                       [[-0.0258, -0.0834]],
#
#                       [[ 0.2804,  0.2683]],
#
#                       [[-0.0018,  0.0570]],
#
#                       [[-0.3806, -0.0973]]])),
#              ('first_conv_layer.bias',
#               tensor([ 0.2539,  0.0529,  0.0676, -0.1681, -0.0650, -0.0951, -0.4898, -0.0130,
#                        0.2221,  0.0905,  0.3001,  0.2161,  0.0296,  0.0407,  0.1278,  0.2687])),
#              ('first_batch_norm.weight',
#               tensor([1.0017, 0.9998, 0.9987, 0.9916, 0.9986, 0.9974, 0.9890, 0.9957, 1.0066,
#                       1.0065, 1.0049, 1.0028, 0.9964, 1.0021, 0.9988, 1.0041])),
#              ('first_batch_norm.bias',
#               tensor([-1.5107e-03, -1.2203e-02, -9.7966e-04,  7.7784e-03, -5.8447e-03,
#                       -4.3822e-03,  3.2722e-03, -4.6944e-04, -7.7617e-03, -8.9668e-04,
#                       -1.7633e-03,  5.9741e-05, -5.6844e-03, -3.8549e-03,  7.5822e-03,
#                        2.2741e-03])),
#              ('first_batch_norm.running_mean',
#               tensor([0.4621, 0.2638, 0.2317, 0.1134, 0.2906, 0.1731, 0.0530, 0.2847, 0.3142,
#                       0.2901, 0.3794, 0.3704, 0.2972, 0.2436, 0.3651, 0.4043])),
#              ('first_batch_norm.running_var',
#               tensor([0.2185, 0.0992, 0.0897, 0.0858, 0.1984, 0.1415, 0.0643, 0.0966, 0.0610,
#                       0.1583, 0.1385, 0.1318, 0.1632, 0.1158, 0.2331, 0.2279])),
#              ('first_batch_norm.num_batches_tracked', tensor(360.)),
#              ('second_conv_layer.weight',
#               tensor([[[-0.0404,  0.0172],
#                        [-0.0322, -0.0696],
#                        [-0.0166,  0.0359],
#                        ...,
#                        [ 0.0551,  0.0061],
#                        [ 0.0706,  0.0877],
#                        [ 0.0193, -0.0068]],
#
#                       [[ 0.0382, -0.0244],
#                        [-0.0426, -0.0470],
#                        [-0.1253,  0.0564],
#                        ...,
#                        [ 0.0872,  0.0615],
#                        [-0.0146, -0.0125],
#                        [ 0.0243, -0.0129]],
#
#                       [[-0.0383, -0.1217],
#                        [-0.0644, -0.0139],
#                        [ 0.0257,  0.0636],
#                        ...,
#                        [-0.0856, -0.0109],
#                        [ 0.0066,  0.0683],
#                        [ 0.1345,  0.0068]],
#
#                       ...,
#
#                       [[-0.0337, -0.0733],
#                        [-0.0654,  0.0880],
#                        [ 0.1024, -0.0110],
#                        ...,
#                        [-0.0844, -0.1124],
#                        [-0.0334, -0.0335],
#                        [-0.0073, -0.0605]],
#
#                       [[-0.0137,  0.0695],
#                        [ 0.0091, -0.0690],
#                        [-0.0855, -0.0500],
#                        ...,
#                        [ 0.0082,  0.0012],
#                        [ 0.0717, -0.0229],
#                        [-0.0763,  0.0143]],
#
#                       [[-0.0015, -0.0763],
#                        [-0.0279, -0.0027],
#                        [-0.0964,  0.0003],
#                        ...,
#                        [ 0.0017, -0.0957],
#                        [-0.0487, -0.0558],
#                        [-0.0049, -0.0478]]])),
#              ('second_conv_layer.bias',
#               tensor([ 0.0190, -0.0294,  0.1174,  0.0712,  0.0653, -0.0290,  0.0773,  0.0364,
#                       -0.0736, -0.0587,  0.1246,  0.0105,  0.0001, -0.0149, -0.0218,  0.0522,
#                       -0.0718,  0.0453,  0.0414, -0.0042, -0.0223, -0.0583, -0.0475, -0.0250,
#                       -0.0477, -0.0588,  0.0266, -0.1208, -0.0384,  0.0174,  0.0582, -0.0260])),
#              ('second_batch_norm.weight',
#               tensor([1.0062, 1.0032, 1.0112, 1.0095, 1.0122, 1.0099, 1.0064, 1.0120, 1.0118,
#                       1.0070, 1.0066, 1.0038, 1.0062, 1.0052, 1.0078, 1.0062, 1.0089, 1.0085,
#                       1.0098, 1.0084, 1.0094, 1.0063, 1.0137, 1.0113, 1.0118, 1.0164, 1.0110,
#                       1.0099, 1.0083, 1.0103, 1.0103, 1.0111])),
#              ('second_batch_norm.bias',
#               tensor([ 0.0006,  0.0006,  0.0011,  0.0061,  0.0023, -0.0041,  0.0002, -0.0057,
#                       -0.0053, -0.0021,  0.0029, -0.0013, -0.0037,  0.0028, -0.0038,  0.0002,
#                        0.0057, -0.0051, -0.0003, -0.0006, -0.0048, -0.0042, -0.0015, -0.0041,
#                        0.0020, -0.0066, -0.0069, -0.0068, -0.0020, -0.0026,  0.0021,  0.0004])),
#              ('second_batch_norm.running_mean',
#               tensor([0.1912, 0.1749, 0.2946, 0.2578, 0.2614, 0.2115, 0.2495, 0.2748, 0.2420,
#                       0.1660, 0.2328, 0.1573, 0.2255, 0.2306, 0.2246, 0.2653, 0.2090, 0.2428,
#                       0.2950, 0.2626, 0.2601, 0.1828, 0.2623, 0.2003, 0.1746, 0.2185, 0.2214,
#                       0.1260, 0.1844, 0.2539, 0.2403, 0.1802])),
#              ('second_batch_norm.running_var',
#               tensor([0.1085, 0.0856, 0.1929, 0.1902, 0.1898, 0.1062, 0.2738, 0.2954, 0.2592,
#                       0.1379, 0.1231, 0.0812, 0.2273, 0.2193, 0.1629, 0.2075, 0.2360, 0.2409,
#                       0.2046, 0.1694, 0.2302, 0.1336, 0.1681, 0.1036, 0.1296, 0.1355, 0.1229,
#                       0.0880, 0.0786, 0.1542, 0.1119, 0.0844])),
#              ('second_batch_norm.num_batches_tracked', tensor(360.)),
#              ('first_linear_layer.weight',
#               tensor([[ 0.0055,  0.0062, -0.0032,  ..., -0.0201, -0.0078,  0.0101],
#                       [-0.0338,  0.0163,  0.0011,  ..., -0.0015, -0.0002, -0.0019],
#                       [ 0.0032, -0.0036,  0.0050,  ..., -0.0119, -0.0028,  0.0080],
#                       ...,
#                       [-0.0113,  0.0079, -0.0147,  ..., -0.0094,  0.0090, -0.0078],
#                       [ 0.0124, -0.0151,  0.0187,  ...,  0.0125,  0.0042,  0.0054],
#                       [-0.0165,  0.0126,  0.0033,  ..., -0.0093,  0.0266,  0.0016]])),
#              ('first_linear_layer.bias',
#               tensor([ 0.0236,  0.0055,  0.0022,  0.0224,  0.0084,  0.0032, -0.0106,  0.0070,
#                       -0.0004,  0.0133, -0.0054,  0.0011,  0.0130,  0.0032, -0.0041,  0.0050,
#                       -0.0054,  0.0055,  0.0065,  0.0088, -0.0013,  0.0167,  0.0075, -0.0023,
#                        0.0173,  0.0222,  0.0152,  0.0060,  0.0192,  0.0150,  0.0247,  0.0013])),
#              ('second_linear_layer.weight',
#               tensor([[ 0.0365,  0.0160,  0.0119, -0.0791,  0.1036,  0.0122,  0.1211,  0.0198,
#                        -0.0610, -0.0054, -0.0559,  0.0459, -0.0194, -0.0483, -0.0800,  0.0312,
#                        -0.0232, -0.1136,  0.1327, -0.1409,  0.0928, -0.1278,  0.0312, -0.0041,
#                         0.0229,  0.0342,  0.1038, -0.0450, -0.0577, -0.0043, -0.0538, -0.1459]])),
#              ('second_linear_layer.bias', tensor([0.0843]))])
